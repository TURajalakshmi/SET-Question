# %%
#1.Perform Recursive Feature Elimination (RFE) using Logistic Regression to select the top 3 features.
# Expected Output:
# Top 3 selected features using RFE: ['alcohol', 'flavanoids', 'od280/od315_of_diluted_wines']

from sklearn.datasets import load_wine
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import pandas as pd

X, y = load_wine(return_X_y=True, as_frame=True)

model = LogisticRegression(max_iter=10000)
rfe = RFE(estimator=model, n_features_to_select=3)
rfe.fit(X, y)

selected_features = X.columns[rfe.support_]

print("Top 3 selected features using RFE:" , selected_features.tolist())
# Out:
# Top 3 selected features using RFE: ['alcohol', 'flavanoids', 'od280/od315_of_diluted_wines']

# %%
#2.Perform PCA for dimensionality reduction and reduce the dataset to 3 components.
# expected output:
#Transformed dataset (3 components):
#[[ -1.2594664   21.27488439  -9.46305689]
#[  7.9576113  -20.76870018   4.43950399]
#[  6.99192304  -9.9559863    2.95856164]
...
#[ 10.80128394  -6.96025023   5.59956528]
#[ -4.87210013  12.42395227 -10.17088928]
#[ -0.34438951   6.36555114  10.77371663]]


from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
import pandas as pd

X, y = load_digits(return_X_y=True, as_frame=True)

pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)
    
print("Transformed dataset (3 components):")
print(X_pca)
# Out:
# Transformed dataset (3 components):
# [[ -1.25946645 -21.27488348   9.46305462]
#  [  7.9576113   20.76869896  -4.43950604]
#  [  6.99192297   9.95598641  -2.95855808]
#  ...
#  [ 10.8012837    6.96025223  -5.59955453]
#  [ -4.87210009 -12.42395362  10.17086635]
#  [ -0.34438963  -6.36554919 -10.77370849]]

# %%
#3.Perform t-SNE dimensionality reduction to reduce the dataset to 2 dimensions.
from sklearn.datasets import load_iris
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import pandas as pd

X, y = load_iris(return_X_y=True, as_frame=True)

model = TSNE(n_components = 2 , random_state=0)
tsne_data = model.fit_transform(X)

plt.scatter(tsne_data[:, 0], tsne_data[:, 1], c=y, cmap="viridis")
plt.colorbar()
plt.title("t-SNE visualization")
plt.show()
# Out:
# C:\Users\Raji\anaconda3\envs\aiml\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\Raji\anaconda3\envs\aiml\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\Raji\anaconda3\envs\aiml\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raji\anaconda3\envs\aiml\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
# ...
